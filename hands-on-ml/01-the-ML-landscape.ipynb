# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
oecd_bli = pd.read_csv("datasets/OECD_BLI.csv", thousands=",")

# %%
oecd_bli["Country"].unique()
# Out:
# array(['Austria', 'Belgium', 'Canada', 'Czechia', 'Denmark', 'Finland',
#        'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland',
#        'Italy', 'Japan', 'Korea', 'Luxembourg', 'Mexico', 'Netherlands',
#        'New Zealand', 'Norway', 'Poland', 'Portugal', 'Slovak Republic',
#        'Spain', 'Sweden', 'Türkiye', 'United Kingdom', 'United States',
#        'Chile', 'Estonia', 'Israel', 'Latvia', 'Slovenia', 'OECD - Total',
#        'Australia', 'Switzerland', 'Brazil', 'Russia', 'South Africa',
#        'Colombia', 'Lithuania', 'Costa Rica'], dtype=object)
