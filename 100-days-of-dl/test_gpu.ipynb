# %%
import tensorflow as tf
# Out:
# 2026-02-18 09:28:45.488469: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
# Out:
# Num GPUs Available:  1

# %%
if tf.config.list_physical_devices("GPU"):
    print("TensorFlow is using the GPU!")
    with tf.device("/GPU:0"):
        a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
        b = tf.constant([[1.0, 1.0], [0.0, 1.0]])
        print(tf.matmul(a, b))
else:
    print("GPU NOT FOUND. Check your drivers and CUDA paths.")
# Out:
# TensorFlow is using the GPU!
# tf.Tensor(
# [[1. 3.]
#  [3. 7.]], shape=(2, 2), dtype=float32)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771387128.891214   49055 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1232 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:10:00.0, compute capability: 8.6
