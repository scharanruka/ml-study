# %%
import tensorflow as tf
# Out:
# 2026-02-21 20:22:38.828617: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
# Out:
# Num GPUs Available:  0
# 2026-02-21 20:22:41.183690: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2026-02-21 20:22:41.183725: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-02-21 20:22:41.183730: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: debian
# 2026-02-21 20:22:41.183734: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: debian
# 2026-02-21 20:22:41.183869: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 550.163.1
# 2026-02-21 20:22:41.183890: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 550.163.1
# 2026-02-21 20:22:41.183894: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 550.163.1

# %%
if tf.config.list_physical_devices("GPU"):
    print("TensorFlow is using the GPU!")
    with tf.device("/GPU:0"):
        a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
        b = tf.constant([[1.0, 1.0], [0.0, 1.0]])
        print(tf.matmul(a, b))
else:
    print("GPU NOT FOUND. Check your drivers and CUDA paths.")
# Out:
# GPU NOT FOUND. Check your drivers and CUDA paths.
